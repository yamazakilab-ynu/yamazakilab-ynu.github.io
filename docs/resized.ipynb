# %%
import os
from pathlib import Path
from PIL import Image

# === 設定 ===
# base_dir = Path(r"C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\album")
base_dir = Path(r"C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img")
output_dir = base_dir / "img_resized"
output_dir.mkdir(exist_ok=True)

# 対象とする画像拡張子
extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".webp"]

# === メイン処理 ===
for img_path in base_dir.glob("*"):
    if img_path.suffix.lower() not in extensions:
        continue  # 画像以外はスキップ

    try:
        # 画像を開く
        with Image.open(img_path) as img:
            # アスペクト比を保持して横幅600pxにリサイズ
            w_percent = 600 / float(img.width)
            new_height = int(img.height * w_percent)
            resized_img = img.resize((600, new_height), Image.LANCZOS)

            # RGB変換（PNG等の透過対策）
            if resized_img.mode in ("RGBA", "P"):
                resized_img = resized_img.convert("RGB")

            # 保存先パス
            out_path = output_dir / img_path.name

            # JPEGで圧縮保存（PNGもJPEGに変換可）
            resized_img.save(out_path, quality=85, optimize=True)

            print(f"✅ Saved: {out_path}")

    except Exception as e:
        print(f"❌ Error processing {img_path}: {e}")
# Out:
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\campus1.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\campus2.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\campus3.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\crystals.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\crystals1.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\crystals2.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\crystals3.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\exp-caloric.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\exp-sp8.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\favicon.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\favicon2.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\favicon3.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\favicon4.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\md-0K.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\md-900K.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\md-half.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\md-mix.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\md-mix.webp
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ml-background.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ml-workflow.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\mumax3-domain.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\p-table.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl-hata-b4.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl-mk-trip.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl-mk10year.png
# ❌ Error processing C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\ppl-mrs.jpg: cannot identify image file 'C:\\Users\\yamaz\\Documents\\GitHub\\yamazakilab\\docs\\img\\ppl-mrs.jpg'
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl-ty-new-170kB.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl-ty-new.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl-ty-old.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl1.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl2.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl3.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl4.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ppl5.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\sp8-xmcd.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\surver.png
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top1.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top10.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top2.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top3.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top4.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top5.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top6.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top7.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top8.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\top9.jpg
# ✅ Saved: C:\Users\yamaz\Documents\GitHub\yamazakilab\docs\img\img_resized\ynu.png
